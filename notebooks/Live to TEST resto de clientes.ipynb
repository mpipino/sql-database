-- %% [markdown]
-- ### Hacerlo desde la Virtual.
--
-- Password para paquetes:
--
-- ![Xirect_SSlSProjects ](attachment:image.png)
--
-- ![aaseCode <
-- aaseCode ](attachment:image0.png)
--
-- ![](attachment:image1.png)
--
--
-- Ticket:
--
-- ![Bodylogic Live to Test July ](attachment:image2.png)
--
-- ![](attachment:image3.png)
--
-- ![](attachment:image4.png)
--
-- ![](attachment:image5.png)
--
-- ![Step 01 container
-- Copy d atabase
-- Disable
-- Parameterize...
-- Add Annotation
-- Add Precedence Constraint
-- Group
-- A utosize
-- Collapse
-- Execute Container
-- Edit Breakooints... ](attachment:image6.png)
--
-- Para chequear si se creó la base de datos nueva:
--
-- [SQL databases - Microsoft Azure](https://portal.azure.com/#blade/HubsExtension/BrowseResource/resourceType/Microsoft.Sql%2Fservers%2Fdatabases)
--
-- ![Thread:
-- Stop Debugging (Shift* Fij
-- FullProcess.dtsx [Design]
-- — Package Explorer O Progress
-- Delyy For Loop Container
-- Validate new Bd Active ](attachment:image7.png)
--
-- Una vez lista la base nueva avisar por Teams:
--
-- ![Body10gic Теат
-- Мои: Рот favor guarden sus cambios Voy а corn.„ ](attachment:image8.png)
--
-- Ejecutar tareas dentro de FULLPROCESS.DTSX, en secuencia:
--
-- ![SetTestData.dtsx 冖 Design]
-- 01 CopyDatabase.dtsx 冖 Design]
-- - package Explorer 0 progress
-- FullProcess.dtsx 冖 Design] ](attachment:image9.png)
--
-- ![MHDæ-IS31 < IS3I
-- 9 OSW 130 S3INV SVbN3nOS3 30 NODVHVdVNO3 833VH
-- ف؟
-- — d24S ](attachment:image10.png)
--
-- ANTES DEL PASO 6 COMPARAR LAS BASES DE TEST \>\>\>\> TEST\_FECHA:
--
-- ![SqSchemaCompareI*
-- Compare
-- bodyIogic.database.xirect.com.80dyLogic_test ](attachment:image11.png)
--
-- Ojo que hay que poner el nombre d<span style="background:red;mso-highlight:red">e la base de datos nueva a mano:</span>
--
-- ![](attachment:image12.png)
--
-- Actualizar:
--
-- ![SqISchemaCompareI* -E
-- Compare
-- Update Y %
-- bodylogic.database.xirect.com.80dyLogic_test
-- Delete
-- C] Table
-- C] Table
-- C] Table
-- Table
-- Procedure
-- Procedure
-- dbo .Commissions_ Distributor_ 80 n usear ned_Summary_ bck0521
-- dbo .Commissions_ Distributor_ Bonusear ned_Summary_ bck0521 _2
-- dbo.tbI_Languages
-- dbo.tbl orders header bckOSD32021
-- dba.
-- dboSP APPRESOURCES GETBYID LANGUAGEIDS
-- 80dyLogic_Live Reader
-- 80dyLogic_Live ReadExecute
-- bodylogiclive
-- bodylogicuser
-- fredydemo
-- xautoshiplive
-- x backofficebodylogiclive
-- x backofficelive
-- x backofficeIive2
-- x backofficeIive3 ](attachment:image13.png)
--
-- Si da error ejecutar el script manualmente:
--
-- ![No issues found
-- Target Update Failed. See Error List for details.
-- Data
-- Tools Operations
-- TABS
-- MIXED
-- No issues found
-- TABS
-- MIXED
-- Schema Compare update (80dyLogic_test > 80dyLogic_LiveToTest 20210701) 2:51:18 PM - 2:52:38 PM
-- X
-- Creating publish preview...
-- Creating master script...
-- Creating database script...
-- Executing update script on database master'
-- Executing update script on database
-- '80dyLogic_LiveToTest 20210701 .
-- View Preview
-- View Script
-- View Script
-- View Results
-- View Results ](attachment:image14.png)
--
-- Para que no de error al tirar tablas:
--
-- ![](attachment:image15.png)
--
-- En SSMS, base:
--
-- ![](attachment:image16.png)
--
-- Borrar:
--
-- ![setv DatabaseName"BodyLogi
-- set var DefaultFiIePrefix "30dyLogic_LiveToTest_
-- set var DefaultDataPath
-- etvar Default Logpath " "
-- o re-enable the scr•
-- T NOEXEC OFF•
-- BEGIN
-- PRINT N • SQLCMO
-- after enablin
-- LC'•O mode
-- execute the followi
-- 43 ](attachment:image17.png)
--
-- Borrar (salvo que habilites en la comparación ALLOW DATA LOSS):
--
-- ![SERROR (N 'Rows were detected.
-- abl
-- se ec
-- -RAISERROR N 'Rows were detected.
-- schema update
-- earnedSumm arybc kø52
-- terminating because data loss
-- ommlsszons
-- The schema
-- 1 rl u or
-- nusear
-- u date is terminatin
-- ummary_ c
-- because data loss mi
-- abl
-- EXISTS
-- abl
-- select top I I from [dbo] . [tbI_Languages]
-- erbckø5ø32ø21])
-- SERROR (N 'Rows we
-- detected.
-- hema update
-- rmina t i ](attachment:image18.png)
--
-- ![SQLQuery8.sqI - bomxirectds.com
-- REVOKE EXECUTE
-- x
-- SQLQuery7.sqI
-- - bo...xirectds.com (145))'
-- SQLQu sc
-- ON : [chat] TO [SodyLogic_Live Reader] CASCADE;
-- cmml&tabaæ.xirect.ccm (SCL Server 15.3.2373.41 - gabalcle)
-- PRINT N 'Dropping Permission Permission. ' ;
-- REVOKE EXECUTE
-- ON SCHEMA:
-- : [chat]
-- TO [30dyLogic_Live ReadExecuteJ
-- CASCADE ;
-- Messages
-- Key _
-- Key _
-- _ Enl _
-- _ Enl _
-- _ tez_Sp:
-- _ Spl
-- _ Spl
-- _ BarmerZÄJes_Spl
-- _ RardESyRuLeE_Sp:
-- Query executed successfully.
-- _ Spl
-- _ C Spl
-- _ E._G.etÄZ E_SpJ _ _
-- bodylogic ](attachment:image19.png)
--
-- Volver a comparar:
--
-- ![No issues found
-- Comparison complete. No differences detected. ](attachment:image20.png)
--
-- TRANSITORIAMENTE: hacer GENERATE SCRIPTS:
--
-- ![IDENTITY_INSERT Cdbo].CLanguage] ON
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- INS ERT
-- [dbo]. [Language)
-- dbo . rLaneuae
-- (CID)
-- [LanguageNameJ ,
-- , r LaneuaeeName1
-- a:om (
-- [FOLDEREXTENSION] ,
-- (FOLDEREXTENSIONI ,
-- r Icon 1,
-- [Status],
-- r Status 1.
-- [Culturelnfo],
-- [Culturelnfol ,
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- Createdl
-- [Createdl
-- (Createdl ](attachment:image21.png)
--
-- Pasar de TEST a la base "nueva con fecha" el contenido de la tabla languaje (la que fué creada, vacía al comparar esquemas)
--
-- Verificar que existan todos los usuarios:
--
-- SELECT DP1.name AS DatabaseRoleName,
--
--    isnull (DP2.name, 'No members') AS DatabaseUserName
--
--  FROM sys.database\_role\_members AS DRM
--
--  RIGHT OUTER JOIN sys.database\_principals AS DP1
--
--    ON DRM.role\_principal\_id = DP1.principal\_id
--
--  LEFT OUTER JOIN sys.database\_principals AS DP2
--
--    ON DRM.member\_principal\_id = DP2.principal\_id
--
-- WHERE DP1.type = 'R'
--
-- ORDER BY DP1.name;
--
-- ![SQLQueryIO.sqI b...xirectds.com -E X
-- SQLQueryg.sqI - bc...xirectcIG.ccm (148)
-- LECT DPI . name AS DatabaseRoIeName,
-- isnull (
-- No members' ) AS
-- 022. name,
-- FROM sys. AS DRM
-- RIGHT OUTER JOIN sys . database_principal
-- ON
-- LEFT
-- ON
-- OER
-- DRM , rol e _ principal_id
-- DPI . principal_id
-- OUTER JOIN sys. database _ principals AS DP2
-- DRM . member_princioal id = DP2.DrincioaI i
-- DPI type
-- DPI.na
-- 13
-- Results Messages
-- DatabaseRoIeName
-- db_backupoperator
-- db
-- datareader
-- db
-- datawfiter
-- db
-- ddladmin
-- db
-- denydatareader
-- db
-- denyd at awfiter
-- db
-- o uner
-- db
-- o uner
-- db
-- o uner
-- db
-- secufityadmin
-- public
-- Read Execute
-- DatabaselJserName
-- No members
-- Body Logic_Test Reader
-- No members
-- No members
-- 80dyLogic Test Admin
-- bodylogict est
-- No members
-- Body Logic_Test Read Execute ](attachment:image22.png)
--
-- ![](attachment:image23.png)
--
-- ![Bodylogic Team ](attachment:image24.png)
--
-- LUEGO BORRAR LA BASE DE DATOS DEPRECATED!!!!!!!!!
